# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset['sex']=dataset['sex'].astype('category')
dataset['sex']=dataset['sex'].cat.codes

# %%
dataset
# Out:
#       age  sex     bmi  children smoker      charges
# 0      19    0  27.900         0    yes  16884.92400
# 1      18    1  33.770         1     no   1725.55230
# 2      28    1  33.000         3     no   4449.46200
# 3      33    1  22.705         0     no  21984.47061
# 4      32    1  28.880         0     no   3866.85520
# ...   ...  ...     ...       ...    ...          ...
# 1333   50    1  30.970         3     no  10600.54830
# 1334   18    0  31.920         0     no   2205.98080
# 1335   18    0  36.850         0     no   1629.83350
# 1336   21    0  25.800         0     no   2007.94500
# 1337   61    0  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset['smoker']=dataset['smoker'].astype('category')
dataset['smoker']=dataset['smoker'].cat.codes

# %%
dataset
# Out:
#       age  sex     bmi  children  smoker      charges
# 0      19    0  27.900         0       1  16884.92400
# 1      18    1  33.770         1       0   1725.55230
# 2      28    1  33.000         3       0   4449.46200
# 3      33    1  22.705         0       0  21984.47061
# 4      32    1  28.880         0       0   3866.85520
# ...   ...  ...     ...       ...     ...          ...
# 1333   50    1  30.970         3       0  10600.54830
# 1334   18    0  31.920         0       0   2205.98080
# 1335   18    0  36.850         0       0   1629.83350
# 1336   21    0  25.800         0       0   2007.94500
# 1337   61    0  29.070         0       1  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'charges'], dtype='object')

# %%
independent=dataset.drop(columns='charges')
independent
# Out:
#       age  sex     bmi  children  smoker
# 0      19    0  27.900         0       1
# 1      18    1  33.770         1       0
# 2      28    1  33.000         3       0
# 3      33    1  22.705         0       0
# 4      32    1  28.880         0       0
# ...   ...  ...     ...       ...     ...
# 1333   50    1  30.970         3       0
# 1334   18    0  31.920         0       0
# 1335   18    0  36.850         0       0
# 1336   21    0  25.800         0       0
# 1337   61    0  29.070         0       1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid={'kernel':['poly','rbf','linear','sigmoid'],'C':[10,100,1000,2000,3000]}
grid=GridSearchCV(SVR(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# C:\Users\JOSE\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'kernel': ['poly', 'rbf', 'linear', 'sigmoid']},
#              verbose=3)

# %%
re=grid.cv_results_
print("The R_Score value for best parameter{}:".format(grid.best_params_))
# Out:
# The R_Score value for best parameter{'C': 3000, 'kernel': 'poly'}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.092064      0.008747         0.016012        0.002532      10
# 1        0.088262      0.010310         0.042030        0.003349      10
# 2        0.068248      0.001940         0.012209        0.000749      10
# 3        0.088262      0.002640         0.017613        0.001202      10
# 4        0.070049      0.000895         0.012810        0.000400     100
# 5        0.083458      0.003500         0.039828        0.001167     100
# 6        0.080457      0.001856         0.012008        0.000633     100
# 7        0.089662      0.002059         0.016812        0.000401     100
# 8        0.110478      0.026345         0.012609        0.000801    1000
# 9        0.101271      0.001722         0.038428        0.000490    1000
# 10       0.094066      0.003635         0.011208        0.000401    1000
# 11       0.101773      0.003631         0.017214        0.000401    1000
# 12       0.153409      0.014240         0.012609        0.000490    2000
# 13       0.108076      0.001675         0.039628        0.001498    2000
# 14       0.117683      0.007064         0.011608        0.000490    2000
# 15       0.107876      0.006887         0.017412        0.000491    2000
# 16       0.318426      0.149558         0.012409        0.000490    3000
# 17       0.123688      0.012684         0.038827        0.001167    3000
# 18       0.145703      0.015171         0.012008        0.000896    3000
# 19       0.099871      0.010691         0.015615        0.003004    3000
#
#    param_kernel                            params  split0_test_score  \
# 0          poly       {'C': 10, 'kernel': 'poly'}           0.054964
# 1           rbf        {'C': 10, 'kernel': 'rbf'}           0.004126
# 2        linear     {'C': 10, 'kernel': 'linear'}           0.377969
# 3       sigmoid    {'C': 10, 'kernel': 'sigmoid'}           0.049644
# 4          poly      {'C': 100, 'kernel': 'poly'}           0.537117
# 5           rbf       {'C': 100, 'kernel': 'rbf'}           0.301041
# 6        linear    {'C': 100, 'kernel': 'linear'}           0.584474
# 7       sigmoid   {'C': 100, 'kernel': 'sigmoid'}           0.478930
# 8          poly     {'C': 1000, 'kernel': 'poly'}           0.828213
# 9           rbf      {'C': 1000, 'kernel': 'rbf'}           0.733334
# 10       linear   {'C': 1000, 'kernel': 'linear'}           0.605304
# 11      sigmoid  {'C': 1000, 'kernel': 'sigmoid'}           0.400044
# 12         poly     {'C': 2000, 'kernel': 'poly'}           0.845581
# 13          rbf      {'C': 2000, 'kernel': 'rbf'}           0.814295
# 14       linear   {'C': 2000, 'kernel': 'linear'}           0.605277
# 15      sigmoid  {'C': 2000, 'kernel': 'sigmoid'}          -0.385658
# 16         poly     {'C': 3000, 'kernel': 'poly'}           0.846874
# 17          rbf      {'C': 3000, 'kernel': 'rbf'}           0.828795
# 18       linear   {'C': 3000, 'kernel': 'linear'}           0.657470
# 19      sigmoid  {'C': 3000, 'kernel': 'sigmoid'}          -1.761871
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.071297          -0.046513          -0.024157
# 1            0.013244          -0.103775          -0.095165
# 2            0.479601           0.317872           0.337979
# 3            0.076323          -0.046798          -0.040824
# 4            0.579373           0.471840           0.537966
# 5            0.338741           0.174086           0.217641
# 6            0.655818           0.553380           0.576939
# 7            0.563200           0.427152           0.451250
# 8            0.802622           0.799348           0.800587
# 9            0.745892           0.687037           0.717769
# 10           0.588725           0.623230           0.537931
# 11           0.366097           0.242217           0.288461
# 12           0.805624           0.816612           0.805133
# 13           0.780971           0.794227           0.793983
# 14           0.583646           0.697368           0.532547
# 15          -0.537098          -0.474912          -0.477335
# 16           0.805331           0.817283           0.805239
# 17           0.790105           0.811123           0.812857
# 18           0.583501           0.697875           0.529117
# 19          -2.139307          -1.704369          -2.340839
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.049652         0.001188        0.051594               16
# 1           -0.101602        -0.056634        0.053486               18
# 2            0.324422         0.367569        0.059777               13
# 3           -0.046521        -0.001635        0.053474               17
# 4            0.424478         0.510155        0.054955               11
# 5            0.183403         0.242982        0.065542               15
# 6            0.546881         0.583498        0.038787               10
# 7            0.432199         0.470546        0.049762               12
# 8            0.735555         0.793265        0.030757                4
# 9            0.649174         0.706641        0.034825                6
# 10           0.616726         0.594383        0.030560                9
# 11           0.351407         0.329645        0.056742               14
# 12           0.754962         0.805582        0.029272                2
# 13           0.733663         0.783428        0.027068                5
# 14           0.681425         0.620053        0.061555                8
# 15          -0.111187        -0.397238        0.150976               19
# 16           0.758988         0.806743        0.028307                1
# 17           0.741835         0.796943        0.030174                3
# 18           0.655785         0.624750        0.060379                7
# 19          -1.048739        -1.799025        0.443311               20

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_input=float(input("Sex male 0 or1:"))
smoker_input=float(input("SMOKER yes 0 or1:"))
# Out:
# Age: 32
# BMI: 43
# Children: 2
# Sex male 0 or1: 0
# SMOKER yes 0 or1: 1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_input,smoker_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[1.92638043e+08]
